# %% [markdown]
# <a href="https://colab.research.google.com/github/nikhil9302/MLH-LHD-BUILD/blob/main/Day-1/headline-sentiment/headline-sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install flair

# %%
from flair.models import TextClassifier
from flair.data import Sentence

classifier = TextClassifier.load('en-sentiment')
sentence = input()
sen = Sentence(sentence)
classifier.predict(sen)

# printed sentence with predicted label "POSITIVE" or "NEGATIVE"
print(f'The sentence "{sentence}" is: Label:', sen.labels[0].value, " Score:", sen.labels[0].score)
# Out:
# 2022-01-10 08:53:39,180 https://nlp.informatik.hu-berlin.de/resources/models/sentiment-curated-distilbert/sentiment-en-mix-distillbert_4.pt not found in cache, downloading to /tmp/tmp0v1cig47
# 100%|██████████| 265512723/265512723 [00:14<00:00, 17775640.62B/s]
# 2022-01-10 08:53:54,439 copying /tmp/tmp0v1cig47 to cache at /root/.flair/models/sentiment-en-mix-distillbert_4.pt
# 2022-01-10 08:53:54,946 removing temp file /tmp/tmp0v1cig47
# 2022-01-10 08:53:54,980 loading file /root/.flair/models/sentiment-en-mix-distillbert_4.pt
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Corruption in politics yet again
# The sentence "Corruption in politics yet again" is: Label: NEGATIVE  Score: 0.9986637830734253

# %%
type(sen.labels[0])
# Out:
# flair.data.Label

# %%
sen.labels[0].score
# Out:
# 0.9986637830734253
